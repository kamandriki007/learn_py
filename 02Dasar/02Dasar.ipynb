# %% [markdown]
# ## Variables
# Problem: Find out total monthly expense given individual expense items

# %%
rent=1220
gas=202.5
groceries=305.6
print(rent)
# Out:
# 1220

# %%
total=rent+gas+groceries
print(total)
# Out:
# 1728.1

# %%
rent=1400
item1="rent"
item2="gas"
item3="groceries"
print("Expense items:",item1,item2,item3)
# Out:
# Expense items: rent gas groceries

# %% [markdown]
# ## Numbers

# %%
12+34
# Out:
# 46

# %%
3-4
# Out:
# -1

# %%
3/4
# Out:
# 0.75

# %%
4*5
# Out:
# 20

# %%
11%2
# % = sisa pembagian
# Out:
# 1

# %%
3**2
# Out:
# 9

# %% [markdown]
# Problem: You are driving from New York City to Baltimore and then going to Pittsburg. You want to know how much total distance you will be travelling?

# %%
nyc_bal=188
bal_pitt=247
total_distance=nyc_bal+bal_pitt
total_distance
# Out:
# 435

# %%
mph=65
time=total_distance/mph
time
# Out:
# 6.6923076923076925

# %%
round(time,2)
# Out:
# 6.69

# %%
round(time,3)
# Out:
# 6.692

# %%
10+2*3
# Out:
# 16

# %%
6-5.7
# Out:
# 0.2999999999999998

# %%
round(6-5.7,2)
# Out:
# 0.3
